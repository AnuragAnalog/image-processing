# %% [markdown]
# # Image Processing
#
# Some of the Image processing techniques.

# %%
# Required modules

import transforms
import numpy as np

from PIL import Image
from ipywidgets import interact
from matplotlib import pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 7)

# %%
# Required functions

def show_image(image):
    plt.imshow(image, cmap='gray')
    plt.axis('off')
    
    return

# %%
# Load the image

image = Image.open('sample.jpeg')
img_arr = np.asarray(image)

show_image(img_arr)

# %%
# Image Negative

transformed_img = transforms.negative(img_arr)
show_image(transformed_img)

# %%
# Log transform

@interact(c=(1, 5, 1))
def interactive_display(c):
    transformed_img = transforms.log_transform(img_arr, c=c)
    show_image(transformed_img)
    
    return
# Out:
# interactive(children=(IntSlider(value=3, description='c', max=5, min=1), Output()), _dom_classes=('widget-inte…

# %%
# Power transform

@interact(gamma=(0.01, 5, 0.05), c=(1, 5, 1))
def interactive_display(gamma, c):
    transformed_img = transforms.power_transform(img_arr, gamma=gamma, c=c)
    show_image(transformed_img)
    
    return
# Out:
# interactive(children=(FloatSlider(value=2.46, description='gamma', max=5.0, min=0.01, step=0.05), IntSlider(va…
